# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = GoogleImageCrawler(
    parser_threads=2,
    downloader_threads=4,
    storage={'root_dir': 'folder/camera'}
)
keyword = [
                'salsa and bachata',
                'AI news',
                'cosmos news',
                'crash',
                'books to read',
                'black dresses',
                'movies',
                'coding',
                'painting artworks',
                'birthday party',
                'dancing class',
                'summer activities',
                'winter activities',
                'anime',
                'memes',
                'music',
                'pottery',
                'OOTD',
                'sneakers and accessories',
                'gym workout',
                'yoga',
                'healthy meals',
                'coffee shops',
                'study setups',
                'travel',
                'beaches',
                'mountains',
                'cities'
                ]
   
for keyword in [
                'himym',
                'himym cast',
                'himym best moments',
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')

# %%
import os
import requests
from serpapi import GoogleSearch
from urllib.parse import urlparse
from PIL import Image
from io import BytesIO
import time

class GoogleImageAPIScraper:
    def __init__(self, output_dir="daily_life_api", api_key=None):
        self.output_dir = output_dir
        os.makedirs(self.output_dir, exist_ok=True)
        self.api_key = api_key or os.getenv("SERPAPI_KEY")
        self.downloaded_count = 0
    
    def search_google_images_api(self, query, max_images=100):
        params = {
            "q": query,
            "tbm": "isch",
            "ijn": "0",
            "api_key": self.api_key
        }
        
        search = GoogleSearch(params)
        results = search.get_dict()
        image_urls = []
        
        if 'images_results' in results:
            for img in results['images_results'][:max_images]:
                if 'original' in img:
                    image_urls.append(img['original'])
        
        return image_urls
    
    def download_image(self, url):
        """Download and save an image from URL"""
        try:
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
            }
            
            response = requests.get(url, headers=headers, stream=True, timeout=10)
            response.raise_for_status()
            
            content_type = response.headers.get('content-type', '')
            if 'image' not in content_type:
                return False
                
            img = Image.open(BytesIO(response.content))
            
            # Determine extension
            ext_map = {
                'image/jpeg': '.jpg',
                'image/png': '.png',
                'image/gif': '.gif',
                'image/webp': '.webp'
            }
            ext = ext_map.get(content_type, '.jpg')
            
            filename = f"daily_{self.downloaded_count}{ext}"
            save_path = os.path.join(self.output_dir, filename)
            
            if img.mode in ('RGBA', 'P'):
                img = img.convert('RGB')
            
            img.save(save_path)
            self.downloaded_count += 1
            print(f"Downloaded {self.downloaded_count}: {save_path}")
            return True
            
        except Exception as e:
            print(f"Failed to download {url}: {str(e)}")
            return False
    
    def scrape_and_download(self, query, max_images=100):
        """Main function using API"""
        if not self.api_key:
            raise ValueError("API key is required for this method")
            
        print(f"Searching Google Images via API for: {query}")
        image_urls = self.search_google_images_api(query, max_images)
        
        print(f"\nFound {len(image_urls)} image URLs. Starting downloads...")
        for url in image_urls[:max_images]:
            self.download_image(url)
            time.sleep(0.5)  # Short delay
            
        print(f"\nFinished! Downloaded {self.downloaded_count} images to {self.output_dir}")

if __name__ == "__main__":
    # Get API key from https://serpapi.com/
    api_key = "78a8e7588892f3d800211d5a242e6f33bbdb013166334f3e64deb6bb6d6bf5f9"  # Replace with your actual key
    
    scraper = GoogleImageAPIScraper(output_dir="daily_life_api", api_key=api_key)
    scraper.scrape_and_download("daily life photography", max_images=500)

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = GoogleImageCrawler(
    parser_threads=2,
    downloader_threads=10,
    storage={'root_dir': 'sources/photos/extra'}
)

for keyword in [
                "cosmos Painting"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')

# %%
import os

def add_prefix_to_images(folder_path, prefix="screenshot"):
    # Traverse through all files in the folder
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            # Check if the file is an image (you can add more extensions if needed)
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.webp')):
                # Split filename and extension
                name, ext = os.path.splitext(filename)
                
                # Create new filename
                new_filename = f"{prefix}_{name}{ext}"
                
                # Full paths for old and new names
                old_path = os.path.join(root, filename)
                new_path = os.path.join(root, new_filename)
                
                # Rename the file
                os.rename(old_path, new_path)
                print(f"Renamed: {filename} -> {new_filename}")

# Usage example:
folder_path = r"D:\image_search_engine_ai-end\sources\photos\extra"
add_prefix_to_images(folder_path)

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = BingImageCrawler(
    parser_threads=1,
    downloader_threads=1,
    storage={'root_dir': 'sources/photos/freedom'}
)
    
for keyword in [
                "national freedom day celebration",
                "independence day parade",
                " flag waving celebration"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1500, file_idx_offset='auto')
        
for keyword in [
                "freedom day fireworks",
                "Damascus freedom day event",
                " cultural celebration"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1500, file_idx_offset='auto')
    
for keyword in [
                "national day military parade",
                " traditional dance celebration",
                "freedom day concert"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1500, file_idx_offset='auto')
    
for keyword in [
                "historical freedom monuments",
                " people celebrating independence",
                "freedom day decorations"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1500, file_idx_offset='auto')
# Out:
# 2025-07-10 04:48:21,509 - WARNING - icrawler.crawler - Due to Bing's limitation, you can only get the first 1000 result. "max_num" has been automatically set to 1000
# 2025-07-10 04:48:21,509 - INFO - icrawler.crawler - start crawling...
# 2025-07-10 04:48:21,509 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-07-10 04:48:21,520 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-07-10 04:48:21,525 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2025-07-10 04:48:26,532 - INFO - downloader - downloader-001 is waiting for new download tasks
# 2025-07-10 04:48:31,037 - INFO - parser - parsing result page https://www.bing.com/images/async?q=national freedom day celebration&first=0
# 2025-07-10 04:48:40,573 - ERROR - downloader - Exception caught when downloading file https://www.greetingswishes.com/wp-content/uploads/2023/01/National-Freedom-Day-Images.jpg, error: HTTPSConnectionPool(host='www.greetingswishes.com', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# 2025-07-10 04:48:48,316 - INFO - downloader - image #1	https://www.greetingswishes.com/wp-content/uploads/2023/01/National-Freedom-Day-Images.jpg
# 2025-07-10 04:48:51,426 - ERROR - downloader - Response status code 403, file https://www.freevector.com/uploads/vector/preview/62747/VecteezyUSA_National_Freedom_DayBackgroundAS0122_generated.jpg
# 2025-07-10 04:48:51,985 - ERROR - downloader - Response status code 403, file https://images.template.net/249630/national-freedom-day-celebration-vector-edit-online.jpg
# 2025-07-10 04:48:52,384 - INFO - downloader - image #2	https://www.greetingswishes.com/wp-content/uploads/2023/01/National-Freedom-Day-Quotes.jpg
# 2025-07-10 04:48:53,395 - INFO - downloader - image #3	https://c8.alamy.com/comp/2WD6MB9/national-freedom-day-concept-1-february-celebration-hand-drawn-flag-of-united-states-with-hands-in-handcuffs-with-a-broken-chain-2WD6MB9.jpg
- INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=580
# 2025-07-10 04:52:20,692 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=560
# 2025-07-10 04:52:20,692 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=600
# 2025-07-10 04:52:20,874 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=620
# 2025-07-10 04:52:21,024 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=640
# 2025-07-10 04:52:21,124 - ERROR - downloader - Exception caught when downloading file http://www.thetower.org/wp-content/uploads/2015/04/Waving-flag.jpg, error: HTTPConnectionPool(host='www.thetower.org', port=80): Max retries exceeded with url: /wp-content/uploads/2015/04/Waving-flag.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000001E9ED440F50>, 'Connection to www.thetower.org timed out. (connect timeout=5)')), remaining retry times: 1
# 2025-07-10 04:52:21,317 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=680
# 2025-07-10 04:52:21,426 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=660
# 2025-07-10 04:52:21,465 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=700
# 2025-07-10 04:52:21,771 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=740
# 2025-07-10 04:52:21,802 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=720
# 2025-07-10 04:52:21,814 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=760
# 2025-07-10 04:52:22,263 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=780
# 2025-07-10 04:52:22,293 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=800
# 2025-07-10 04:52:22,301 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=820
# 2025-07-10 04:52:22,311 - INFO - feeder - thread feeder-001 exit
# 2025-07-10 04:52:22,618 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=840
# 2025-07-10 04:52:22,675 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=860
# 2025-07-10 04:52:22,775 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=880
# 2025-07-10 04:52:22,914 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=900
# 2025-07-10 04:52:22,992 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=920
# 2025-07-10 04:52:23,075 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=940
# 2025-07-10 04:52:23,275 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=960
# 2025-07-10 04:52:23,285 - INFO - parser - parsing result page https://www.bing.com/images/async?q= flag waving celebration&first=980
# 2025-07-10 04:52:25,102 - INFO - parser - no more page urls for thread parser-001 to parse
# 2025-07-10 04:52:25,102 - INFO - parser - thread parser-001 exit
# 2025-07-10 04:52:25,292 - INFO - parser - no more page urls for thread parser-001 to parse
# 2025-07-10 04:52:25,292 - INFO - parser - thread parser-001 exit
# 2025-07-10 04:52:25,308 - INFO - parser - no more page urls for thread parser-001 to parse
# ...
# 2025-07-10 06:21:32,826 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:34,836 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:36,842 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:38,845 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:40,846 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:42,861 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:44,878 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:46,894 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:48,899 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:50,909 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:52,913 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:54,917 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:56,920 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:21:58,921 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:00,927 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:02,937 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:04,938 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:06,939 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:08,946 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:10,951 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:12,952 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:14,967 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:16,975 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:18,980 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:20,985 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:23,002 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:25,005 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:27,011 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:29,020 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:31,035 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:33,037 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:35,041 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:37,049 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:39,057 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:41,070 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:43,071 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:45,079 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:47,088 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:49,095 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:51,104 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:53,109 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:55,117 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:57,125 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:22:59,136 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:01,140 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:03,151 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:05,162 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:07,168 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:09,175 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:11,182 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:13,202 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:15,203 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:17,219 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:19,220 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:21,235 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:23,236 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:25,237 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:27,240 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:29,254 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:31,257 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:33,264 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:35,268 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:37,274 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:39,279 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:41,288 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:43,295 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:45,296 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:47,299 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:49,312 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:51,314 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:53,323 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:55,334 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:57,344 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:23:59,348 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:01,362 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:03,369 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:05,383 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:07,387 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:09,392 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:11,408 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:13,421 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:15,435 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:17,453 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:19,466 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:21,477 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:23,491 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:25,503 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:27,523 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:29,537 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:31,555 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:33,561 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:35,573 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:37,575 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:39,580 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:41,584 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:43,593 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:45,598 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:47,600 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:49,612 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:51,614 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:53,623 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:55,624 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:57,629 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:24:59,631 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:01,632 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:03,648 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:05,650 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:07,664 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:09,666 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:11,682 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:13,683 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:15,699 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:17,702 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:19,703 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:21,719 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:23,720 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:25,732 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:27,739 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:29,754 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:31,756 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:33,761 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:35,774 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:37,791 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:39,792 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:41,808 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:43,811 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:45,814 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:47,816 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:49,826 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:51,828 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:53,835 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:55,845 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:57,859 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:25:59,861 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:01,871 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:03,879 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:05,887 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:07,893 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:09,900 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:11,910 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:13,926 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:15,930 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:17,936 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:19,951 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:21,954 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:23,968 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:25,972 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:27,987 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:29,991 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:32,006 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:34,008 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:36,023 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:38,038 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:40,039 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:42,043 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:44,058 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:46,061 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:48,067 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:50,082 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:52,097 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:54,108 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:56,112 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:26:58,124 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:00,129 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:02,144 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:04,152 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:06,165 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:08,179 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:10,196 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:12,202 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:14,209 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:16,223 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:18,229 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:20,235 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:22,238 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:24,254 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:26,264 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:28,276 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:30,285 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:32,299 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:34,314 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:36,321 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:38,334 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:40,337 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:42,344 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:44,347 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:46,360 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:48,365 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:50,380 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:52,387 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:54,402 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:56,410 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:27:58,420 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:28:00,431 - INFO - parser - parser-001 is waiting for new page urls
# 2025-07-10 06:28:02,443 - INFO - parser - parser-001 is waiting for new page urls

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = BingImageCrawler(
    parser_threads=1,
    downloader_threads=1,
    storage={'root_dir': 'sources/photos/media'}
)
    
for keyword in [
                "black and white fashion photography",
                "monochrome portrait studio lighting",
                "black and white celebrity portraits"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
        
for keyword in [
                "black and white industrial photography",
                "monochrome machinery details",
                "black and white automotive photography"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "black and white wildlife photography",
                "monochrome animal portraits",
                "black and white underwater photography"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "black and white sports photography",
                "monochrome action shots",
                "black and white dance photography"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = BingImageCrawler(
    parser_threads=1,
    downloader_threads=1,
    storage={'root_dir': 'sources/photos/media'}
)
    
for keyword in [
                "lovely golden retriever",
                "cute labrador puppy",
                "adorable beagle dog"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
        
for keyword in [
                "playful corgi dog",
                "happy husky puppy",
                "smiling poodle dog"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "fluffy samoyed dog",
                "tiny chihuahua puppy",
                "cuddly shih tzu"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "dachshund puppy playing",
                "border collie smiling",
                "pomeranian dog cute"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')

# %%
from icrawler.builtin import GoogleImageCrawler, BingImageCrawler

google_crawler = BingImageCrawler(
    parser_threads=1,
    downloader_threads=1,
    storage={'root_dir': 'sources/photos/media'}
)

        
for keyword in [
                "lean protein meals",
                "whole grain foods",
                "low fat dairy"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "superfoods",
                "plant based diet",
                "organic produce"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
    
for keyword in [
                "balanced meals",
                "heart healthy foods",
                "antioxidant rich foods"
                ]:
    google_crawler.crawl(
        keyword=keyword, max_num=1000, file_idx_offset='auto')
